# %% [markdown]
# # Install ABIDES

# %%
# Install python 3.10 + compatible pip version
# !sudo apt-get update -y
# !sudo apt-get install python3.10 -y
# !sudo apt-get install python3.10-distutils -y
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --set python3 /usr/bin/python3.10
# !sudo apt-get install python3.10-distutils -y
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.10 get-pip.py
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,321 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,664 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,708 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,235 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,956 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,688 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,649 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,830 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,533 kB]
# Fetched 29.0 MB in 6s (5,088 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.10 is already the newest version (3.10.12-1~22.04.9).
# python3.10 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in manual mode
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# --2025-03-01 18:48:28--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2300175 (2.2M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.19M  --.-KB/s    in 0.06s
#
# 2025-03-01 18:48:29 (37.2 MB/s) - ‘get-pip.py’ saved [2300175/2300175]
#
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting setuptools
#   Downloading setuptools-75.8.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.0 MB/s eta 0:00:00
# Downloading setuptools-75.8.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.9 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools, pip
# Successfully installed pip-25.0.1 setuptools-75.8.2 wheel-0.45.1

# %%
# !python --version # require 3.10
# Out:
# Python 3.10.12

# %%
# Install system dependencies
# !apt-get install -y python3-dev graphviz libgraphviz-dev pkg-config

# Clone ABIDES frmo github
# !git clone --depth 1 https://github.com/jpmorganchase/abides-jpmc-public.git
# %cd abides-jpmc-public

# !sed -i 's/python /python3.10 /g' install.sh # ensure the correct python verison is used
# !chmod +x install.sh # Make the install script executable
# !./install.sh
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-dev is already the newest version (3.10.6-1~22.04.1).
# python3-dev set to manually installed.
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# The following packages were automatically installed and are no longer required:
#   libbz2-dev libpkgconf3 libreadline-dev
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgvc6-plugins-gtk
#   librsvg2-common libxdot4
# Suggested packages:
#   gvfs
# The following packages will be REMOVED:
#   pkgconf r-base-dev
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk librsvg2-common libxdot4 pkg-config
# 0 upgraded, 10 newly installed, 2 to remove and 32 not upgraded.
# Need to get 2,482 kB of archives.
# After this operation, 7,670 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 pkg-config amd64 0.29.2-1ubuntu3 [48.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libxdot4 amd64 2.42.2-6ubuntu0.1 [16.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgvc6-plugins-gtk amd64 2.42.2-6ubuntu0.1 [22.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgraphviz-dev amd64 2.42.2-6ubuntu0.1 [58.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Fetched 2,482 kB in 1s (3,533 kB/s)
# (Reading database ... 124947 files and directories currently installed.)
# Removing r-base-dev (4.4.2-1.2204.0) ...
# dpkg: pkgconf: dependency problems, but removing anyway as you requested:
#  libsndfile1-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libopencv-dev depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libmkl-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libjack-dev depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libgphoto2-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libfontconfig-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#
# Removing pkgconf (1.8.0-1) ...
# Removing 'diversion of /usr/bin/pkg-config to /usr/bin/pkg-config.real by pkgconf'
# Removing 'diversion of /usr/share/aclocal/pkg.m4 to /usr/share/aclocal/pkg.real.m4 by pkgconf'
# Removing 'diversion of /usr/share/man/man1/pkg-config.1.gz to /usr/share/man/man1/pkg-config.real.1.gz by pkgconf'
# Removing 'diversion of /usr/share/pkg-config-crosswrapper to /usr/share/pkg-config-crosswrapper.real by pkgconf'
# Selecting previously unselected package pkg-config.
# (Reading database ... 124923 files and directories currently installed.)
# Preparing to unpack .../0-pkg-config_0.29.2-1ubuntu3_amd64.deb ...
# Unpacking pkg-config (0.29.2-1ubuntu3) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../1-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../2-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../3-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../4-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../5-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../6-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../7-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../8-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../9-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up pkg-config (0.29.2-1ubuntu3) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Cloning into 'abides-jpmc-public'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 140 (delta 22), reused 96 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (140/140), 1.53 MiB | 10.37 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/abides-jpmc-public
# Collecting coloredlogs==15.0.1 (from -r requirements.txt (line 1))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting gym==0.18.0 (from -r requirements.txt (line 2))
#   Downloading gym-0.18.0.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.9 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting p_tqdm==1.3.3 (from -r requirements-dev.txt (line 1))
#   Downloading p_tqdm-1.3.3.tar.gz (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pre-commit==2.13 (from -r requirements-dev.txt (line 2))
#   Downloading pre_commit-2.13.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pytest==6.2.4 (from -r requirements-dev.txt (line 3))
#   Downloading pytest-6.2.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting pytest-cov==2.12.1 (from -r requirements-dev.txt (line 4))
#   Downloading pytest_cov-2.12.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting sphinx==3.5.4 (from -r requirements-dev.txt (line 5))
#   Downloading Sphinx-3.5.4-py3-none-any.whl.metadata (7.9 kB)
# Collecting sphinx-autodoc-typehints==1.12.0 (from -r requirements-dev.txt (line 6))
#   Downloading sphinx_autodoc_typehints-1.12.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting sphinx-book-theme==0.0.42 (from -r requirements-dev.txt (line 7))
#   Downloading sphinx_book_theme-0.0.42-py3-none-any.whl.metadata (4.1 kB)
# Collecting tqdm (from p_tqdm==1.3.3->-r requirements-dev.txt (line 1))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting pathos (from p_tqdm==1.3.3->-r requirements-dev.txt (line 1))
#   Downloading pathos-0.3.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from p_tqdm==1.3.3->-r requirements-dev.txt (line 1)) (1.16.0)
# Collecting cfgv>=2.0.0 (from pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading identify-2.6.8-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml>=5.1 (from pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting toml (from pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting virtualenv>=20.0.8 (from pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading virtualenv-20.29.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting attrs>=19.2.0 (from pytest==6.2.4->-r requirements-dev.txt (line 3))
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting iniconfig (from pytest==6.2.4->-r requirements-dev.txt (line 3))
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting packaging (from pytest==6.2.4->-r requirements-dev.txt (line 3))
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pluggy<1.0.0a1,>=0.12 (from pytest==6.2.4->-r requirements-dev.txt (line 3))
#   Downloading pluggy-1.0.0.dev0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting py>=1.8.2 (from pytest==6.2.4->-r requirements-dev.txt (line 3))
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting coverage>=5.2.1 (from pytest-cov==2.12.1->-r requirements-dev.txt (line 4))
#   Downloading coverage-7.6.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# Collecting sphinxcontrib-applehelp (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-htmlhelp (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting sphinxcontrib-qthelp (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting Jinja2>=2.3 (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting Pygments>=2.0 (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting docutils<0.17,>=0.12 (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting snowballstemmer>=1.1 (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting babel>=1.3 (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting alabaster<0.8,>=0.7 (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading alabaster-0.7.16-py3-none-any.whl.metadata (2.9 kB)
# Collecting imagesize (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting requests>=2.5.0 (from sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from sphinx==3.5.4->-r requirements-dev.txt (line 5)) (75.8.2)
# Collecting click (from sphinx-book-theme==0.0.42->-r requirements-dev.txt (line 7))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting pydata-sphinx-theme~=0.4.1 (from sphinx-book-theme==0.0.42->-r requirements-dev.txt (line 7))
#   Downloading pydata_sphinx_theme-0.4.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting beautifulsoup4<5,>=4.6.1 (from sphinx-book-theme==0.0.42->-r requirements-dev.txt (line 7))
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4<5,>=4.6.1->sphinx-book-theme==0.0.42->-r requirements-dev.txt (line 7))
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4<5,>=4.6.1->sphinx-book-theme==0.0.42->-r requirements-dev.txt (line 7))
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.3->sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.5.0->sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.5.0->sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.5.0->sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.5.0->sphinx==3.5.4->-r requirements-dev.txt (line 5))
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.0.8->pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting filelock<4,>=3.12.2 (from virtualenv>=20.0.8->pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting platformdirs<5,>=3.9.1 (from virtualenv>=20.0.8->pre-commit==2.13->-r requirements-dev.txt (line 2))
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting ppft>=1.7.6.9 (from pathos->p_tqdm==1.3.3->-r requirements-dev.txt (line 1))
#   Downloading ppft-1.7.6.9-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.9 (from pathos->p_tqdm==1.3.3->-r requirements-dev.txt (line 1))
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.5 (from pathos->p_tqdm==1.3.3->-r requirements-dev.txt (line 1))
#   Downloading pox-0.3.5-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.17 (from pathos->p_tqdm==1.3.3->-r requirements-dev.txt (line 1))
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Downloading pre_commit-2.13.0-py2.py3-none-any.whl (190 kB)
# Downloading pytest-6.2.4-py3-none-any.whl (280 kB)
# Downloading pytest_cov-2.12.1-py2.py3-none-any.whl (20 kB)
# Downloading Sphinx-3.5.4-py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 78.8 MB/s eta 0:00:00
# Downloading sphinx_autodoc_typehints-1.12.0-py3-none-any.whl (9.4 kB)
# Downloading sphinx_book_theme-0.0.42-py3-none-any.whl (89 kB)
# Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 120.7 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading coverage-7.6.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
# Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 22.7 MB/s eta 0:00:00
# Downloading identify-2.6.8-py2.py3-none-any.whl (99 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading pluggy-1.0.0.dev0-py2.py3-none-any.whl (17 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Downloading pydata_sphinx_theme-0.4.3-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 89.9 MB/s eta 0:00:00
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.3 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 36.4 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Downloading virtualenv-20.29.2-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 86.5 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading pathos-0.3.3-py3-none-any.whl (82 kB)
# Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
# Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
# Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
# Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (146 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading pox-0.3.5-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.9-py3-none-any.whl (56 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Building wheels for collected packages: p_tqdm
#   Building wheel for p_tqdm (setup.py) ... done
#   Created wheel for p_tqdm: filename=p_tqdm-1.3.3-py3-none-any.whl size=4028 sha256=8f07fe497d4964a0eaaa2a23f0a608811cf1fefe1301fe83e0986fcaf78f7249
#   Stored in directory: /root/.cache/pip/wheels/8a/1b/bd/35ba8e33273ca7dfd82a55b91303518cac7981e7f3b32f858c
# Successfully built p_tqdm
# Installing collected packages: snowballstemmer, distlib, urllib3, typing-extensions, tqdm, toml, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, soupsieve, pyyaml, Pygments, py, ppft, pox, pluggy, platformdirs, packaging, nodeenv, MarkupSafe, iniconfig, imagesize, idna, identify, filelock, docutils, dill, coverage, click, charset-normalizer, cfgv, certifi, babel, attrs, alabaster, virtualenv, requests, pytest, multiprocess, Jinja2, beautifulsoup4, sphinx, pytest-cov, pre-commit, pathos, sphinx-autodoc-typehints, pydata-sphinx-theme, p_tqdm, sphinx-book-theme
# Successfully installed Jinja2-3.1.5 MarkupSafe-3.0.2 Pygments-2.19.1 alabaster-0.7.16 attrs-25.1.0 babel-2.17.0 beautifulsoup4-4.13.3 certifi-2025.1.31 cfgv-3.4.0 charset-normalizer-3.4.1 click-8.1.8 coverage-7.6.12 dill-0.3.9 distlib-0.3.9 docutils-0.16 filelock-3.17.0 identify-2.6.8 idna-3.10 imagesize-1.4.1 iniconfig-2.0.0 multiprocess-0.70.17 nodeenv-1.9.1 p_tqdm-1.3.3 packaging-24.2 pathos-0.3.3 platformdirs-4.3.6 pluggy-1.0.0.dev0 pox-0.3.5 ppft-1.7.6.9 pre-commit-2.13.0 py-1.11.0 pydata-sphinx-theme-0.4.3 pytest-6.2.4 pytest-cov-2.12.1 pyyaml-6.0.2 requests-2.32.3 snowballstemmer-2.2.0 soupsieve-2.6 sphinx-3.5.4 sphinx-autodoc-typehints-1.12.0 sphinx-book-theme-0.0.42 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0 toml-0.10.2 tqdm-4.67.1 typing-extensions-4.12.2 urllib3-2.3.0 virtualenv-20.29.2
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:79: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:79: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating abides_core.egg-info
# writing abides_core.egg-info/PKG-INFO
# writing dependency_links to abides_core.egg-info/dependency_links.txt
# writing top-level names to abides_core.egg-info/top_level.txt
# writing manifest file 'abides_core.egg-info/SOURCES.txt'
# reading manifest file 'abides_core.egg-info/SOURCES.txt'
# writing manifest file 'abides_core.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib/abides_core
# copying abides_core/utils.py -> build/lib/abides_core
# copying abides_core/agent.py -> build/lib/abides_core
# copying abides_core/message.py -> build/lib/abides_core
# copying abides_core/kernel.py -> build/lib/abides_core
# copying abides_core/latency_model.py -> build/lib/abides_core
# copying abides_core/generators.py -> build/lib/abides_core
# copying abides_core/abides.py -> build/lib/abides_core
# copying abides_core/__init__.py -> build/lib/abides_core
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/utils.py -> build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/agent.py -> build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/message.py -> build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/kernel.py -> build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/latency_model.py -> build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/generators.py -> build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/abides.py -> build/bdist.linux-x86_64/egg/abides_core
# copying build/lib/abides_core/__init__.py -> build/bdist.linux-x86_64/egg/abides_core
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/agent.py to agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/message.py to message.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/kernel.py to kernel.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/latency_model.py to latency_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/generators.py to generators.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/abides.py to abides.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_core/__init__.py to __init__.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# installing scripts to build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# running install_scripts
# running build_scripts
# creating build/scripts-3.10
# copying and adjusting scripts/abides -> build/scripts-3.10
# changing mode of build/scripts-3.10/abides from 644 to 755
# creating build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.10/abides -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/abides to 755
# copying abides_core.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_core.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_core.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_core.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/abides_core-0.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing abides_core-0.0.0-py3.10.egg
# Copying abides_core-0.0.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding abides-core 0.0.0 to easy-install.pth file
# Installing abides script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/abides_core-0.0.0-py3.10.egg
# Processing dependencies for abides-core==0.0.0
# Finished processing dependencies for abides-core==0.0.0
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:79: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:79: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating abides_markets.egg-info
# writing abides_markets.egg-info/PKG-INFO
# writing dependency_links to abides_markets.egg-info/dependency_links.txt
# writing top-level names to abides_markets.egg-info/top_level.txt
# writing manifest file 'abides_markets.egg-info/SOURCES.txt'
# reading manifest file 'abides_markets.egg-info/SOURCES.txt'
# writing manifest file 'abides_markets.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib/tests
# copying tests/test_orders.py -> build/lib/tests
# copying tests/test_ou_process.py -> build/lib/tests
# copying tests/agent_utils_test.py -> build/lib/tests
# copying tests/test_generators.py -> build/lib/tests
# copying tests/test_sim.py -> build/lib/tests
# copying tests/test_gym_runner.py -> build/lib/tests
# copying tests/__init__.py -> build/lib/tests
# creating build/lib/abides_markets
# copying abides_markets/price_level.py -> build/lib/abides_markets
# copying abides_markets/generators.py -> build/lib/abides_markets
# copying abides_markets/__init__.py -> build/lib/abides_markets
# copying abides_markets/orders.py -> build/lib/abides_markets
# copying abides_markets/order_book.py -> build/lib/abides_markets
# creating build/lib/tests/orderbook
# copying tests/orderbook/test_price_to_comply.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_modify_order.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_limit_orders.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_price_level.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_orderbook.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_cancel_order.py -> build/lib/tests/orderbook
# copying tests/orderbook/__init__.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_data_methods.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_replace_order.py -> build/lib/tests/orderbook
# copying tests/orderbook/test_market_orders.py -> build/lib/tests/orderbook
# creating build/lib/abides_markets/oracles
# copying abides_markets/oracles/sparse_mean_reverting_oracle.py -> build/lib/abides_markets/oracles
# copying abides_markets/oracles/oracle.py -> build/lib/abides_markets/oracles
# copying abides_markets/oracles/__init__.py -> build/lib/abides_markets/oracles
# copying abides_markets/oracles/mean_reverting_oracle.py -> build/lib/abides_markets/oracles
# creating build/lib/abides_markets/configs
# copying abides_markets/configs/rmsc03.py -> build/lib/abides_markets/configs
# copying abides_markets/configs/rmsc04.py -> build/lib/abides_markets/configs
# copying abides_markets/configs/__init__.py -> build/lib/abides_markets/configs
# creating build/lib/abides_markets/models
# copying abides_markets/models/order_size_model.py -> build/lib/abides_markets/models
# copying abides_markets/models/__init__.py -> build/lib/abides_markets/models
# creating build/lib/abides_markets/utils
# copying abides_markets/utils/__init__.py -> build/lib/abides_markets/utils
# creating build/lib/abides_markets/agents
# copying abides_markets/agents/utils.py -> build/lib/abides_markets/agents
# copying abides_markets/agents/noise_agent.py -> build/lib/abides_markets/agents
# copying abides_markets/agents/value_agent.py -> build/lib/abides_markets/agents
# copying abides_markets/agents/financial_agent.py -> build/lib/abides_markets/agents
# copying abides_markets/agents/exchange_agent.py -> build/lib/abides_markets/agents
# copying abides_markets/agents/__init__.py -> build/lib/abides_markets/agents
# copying abides_markets/agents/trading_agent.py -> build/lib/abides_markets/agents
# creating build/lib/abides_markets/messages
# copying abides_markets/messages/market.py -> build/lib/abides_markets/messages
# copying abides_markets/messages/marketdata.py -> build/lib/abides_markets/messages
# copying abides_markets/messages/order.py -> build/lib/abides_markets/messages
# copying abides_markets/messages/orderbook.py -> build/lib/abides_markets/messages
# copying abides_markets/messages/query.py -> build/lib/abides_markets/messages
# copying abides_markets/messages/__init__.py -> build/lib/abides_markets/messages
# creating build/lib/abides_markets/agents/background_v2
# copying abides_markets/agents/background_v2/core_background_agent.py -> build/lib/abides_markets/agents/background_v2
# copying abides_markets/agents/background_v2/__init__.py -> build/lib/abides_markets/agents/background_v2
# creating build/lib/abides_markets/agents/market_makers
# copying abides_markets/agents/market_makers/adaptive_market_maker_agent.py -> build/lib/abides_markets/agents/market_makers
# copying abides_markets/agents/market_makers/__init__.py -> build/lib/abides_markets/agents/market_makers
# creating build/lib/abides_markets/agents/examples
# copying abides_markets/agents/examples/momentum_agent.py -> build/lib/abides_markets/agents/examples
# copying abides_markets/agents/examples/__init__.py -> build/lib/abides_markets/agents/examples
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_orders.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_ou_process.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/agent_utils_test.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_generators.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_sim.py -> build/bdist.linux-x86_64/egg/tests
# creating build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_price_to_comply.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_modify_order.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_limit_orders.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_price_level.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_orderbook.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_cancel_order.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/__init__.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_data_methods.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_replace_order.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/orderbook/test_market_orders.py -> build/bdist.linux-x86_64/egg/tests/orderbook
# copying build/lib/tests/test_gym_runner.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/__init__.py -> build/bdist.linux-x86_64/egg/tests
# creating build/bdist.linux-x86_64/egg/abides_markets
# copying build/lib/abides_markets/price_level.py -> build/bdist.linux-x86_64/egg/abides_markets
# creating build/bdist.linux-x86_64/egg/abides_markets/oracles
# copying build/lib/abides_markets/oracles/sparse_mean_reverting_oracle.py -> build/bdist.linux-x86_64/egg/abides_markets/oracles
# copying build/lib/abides_markets/oracles/oracle.py -> build/bdist.linux-x86_64/egg/abides_markets/oracles
# copying build/lib/abides_markets/oracles/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/oracles
# copying build/lib/abides_markets/oracles/mean_reverting_oracle.py -> build/bdist.linux-x86_64/egg/abides_markets/oracles
# creating build/bdist.linux-x86_64/egg/abides_markets/configs
# copying build/lib/abides_markets/configs/rmsc03.py -> build/bdist.linux-x86_64/egg/abides_markets/configs
# copying build/lib/abides_markets/configs/rmsc04.py -> build/bdist.linux-x86_64/egg/abides_markets/configs
# copying build/lib/abides_markets/configs/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/configs
# creating build/bdist.linux-x86_64/egg/abides_markets/models
# copying build/lib/abides_markets/models/order_size_model.py -> build/bdist.linux-x86_64/egg/abides_markets/models
# copying build/lib/abides_markets/models/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/models
# creating build/bdist.linux-x86_64/egg/abides_markets/utils
# copying build/lib/abides_markets/utils/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/utils
# copying build/lib/abides_markets/generators.py -> build/bdist.linux-x86_64/egg/abides_markets
# creating build/bdist.linux-x86_64/egg/abides_markets/agents
# copying build/lib/abides_markets/agents/utils.py -> build/bdist.linux-x86_64/egg/abides_markets/agents
# creating build/bdist.linux-x86_64/egg/abides_markets/agents/background_v2
# copying build/lib/abides_markets/agents/background_v2/core_background_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents/background_v2
# copying build/lib/abides_markets/agents/background_v2/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/agents/background_v2
# creating build/bdist.linux-x86_64/egg/abides_markets/agents/market_makers
# copying build/lib/abides_markets/agents/market_makers/adaptive_market_maker_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents/market_makers
# copying build/lib/abides_markets/agents/market_makers/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/agents/market_makers
# copying build/lib/abides_markets/agents/noise_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents
# copying build/lib/abides_markets/agents/value_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents
# copying build/lib/abides_markets/agents/financial_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents
# creating build/bdist.linux-x86_64/egg/abides_markets/agents/examples
# copying build/lib/abides_markets/agents/examples/momentum_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents/examples
# copying build/lib/abides_markets/agents/examples/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/agents/examples
# copying build/lib/abides_markets/agents/exchange_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents
# copying build/lib/abides_markets/agents/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/agents
# copying build/lib/abides_markets/agents/trading_agent.py -> build/bdist.linux-x86_64/egg/abides_markets/agents
# creating build/bdist.linux-x86_64/egg/abides_markets/messages
# copying build/lib/abides_markets/messages/market.py -> build/bdist.linux-x86_64/egg/abides_markets/messages
# copying build/lib/abides_markets/messages/marketdata.py -> build/bdist.linux-x86_64/egg/abides_markets/messages
# copying build/lib/abides_markets/messages/order.py -> build/bdist.linux-x86_64/egg/abides_markets/messages
# copying build/lib/abides_markets/messages/orderbook.py -> build/bdist.linux-x86_64/egg/abides_markets/messages
# copying build/lib/abides_markets/messages/query.py -> build/bdist.linux-x86_64/egg/abides_markets/messages
# copying build/lib/abides_markets/messages/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets/messages
# copying build/lib/abides_markets/__init__.py -> build/bdist.linux-x86_64/egg/abides_markets
# copying build/lib/abides_markets/orders.py -> build/bdist.linux-x86_64/egg/abides_markets
# copying build/lib/abides_markets/order_book.py -> build/bdist.linux-x86_64/egg/abides_markets
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_orders.py to test_orders.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_ou_process.py to test_ou_process.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/agent_utils_test.py to agent_utils_test.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_generators.py to test_generators.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_sim.py to test_sim.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_price_to_comply.py to test_price_to_comply.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_modify_order.py to test_modify_order.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_limit_orders.py to test_limit_orders.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_price_level.py to test_price_level.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_orderbook.py to test_orderbook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_cancel_order.py to test_cancel_order.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_data_methods.py to test_data_methods.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_replace_order.py to test_replace_order.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/orderbook/test_market_orders.py to test_market_orders.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_gym_runner.py to test_gym_runner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/price_level.py to price_level.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/oracles/sparse_mean_reverting_oracle.py to sparse_mean_reverting_oracle.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/oracles/oracle.py to oracle.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/oracles/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/oracles/mean_reverting_oracle.py to mean_reverting_oracle.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/configs/rmsc03.py to rmsc03.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/configs/rmsc04.py to rmsc04.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/configs/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/models/order_size_model.py to order_size_model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/models/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/generators.py to generators.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/background_v2/core_background_agent.py to core_background_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/background_v2/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/market_makers/adaptive_market_maker_agent.py to adaptive_market_maker_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/market_makers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/noise_agent.py to noise_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/value_agent.py to value_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/financial_agent.py to financial_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/examples/momentum_agent.py to momentum_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/examples/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/exchange_agent.py to exchange_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/agents/trading_agent.py to trading_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/messages/market.py to market.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/messages/marketdata.py to marketdata.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/messages/order.py to order.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/messages/orderbook.py to orderbook.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/messages/query.py to query.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/messages/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/orders.py to orders.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_markets/order_book.py to order_book.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_markets.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_markets.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_markets.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_markets.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/abides_markets-0.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing abides_markets-0.0.0-py3.10.egg
# Copying abides_markets-0.0.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding abides-markets 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/abides_markets-0.0.0-py3.10.egg
# Processing dependencies for abides-markets==0.0.0
# Finished processing dependencies for abides-markets==0.0.0
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:79: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:79: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating abides_gym.egg-info
# writing abides_gym.egg-info/PKG-INFO
# writing dependency_links to abides_gym.egg-info/dependency_links.txt
# writing top-level names to abides_gym.egg-info/top_level.txt
# writing manifest file 'abides_gym.egg-info/SOURCES.txt'
# reading manifest file 'abides_gym.egg-info/SOURCES.txt'
# writing manifest file 'abides_gym.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib/abides_gym
# copying abides_gym/__init__.py -> build/lib/abides_gym
# creating build/lib/abides_gym/experimental_agents
# copying abides_gym/experimental_agents/core_gym_agent.py -> build/lib/abides_gym/experimental_agents
# copying abides_gym/experimental_agents/financial_gym_agent.py -> build/lib/abides_gym/experimental_agents
# copying abides_gym/experimental_agents/__init__.py -> build/lib/abides_gym/experimental_agents
# creating build/lib/abides_gym/envs
# copying abides_gym/envs/markets_execution_environment_v0.py -> build/lib/abides_gym/envs
# copying abides_gym/envs/core_environment.py -> build/lib/abides_gym/envs
# copying abides_gym/envs/markets_daily_investor_environment_v0.py -> build/lib/abides_gym/envs
# copying abides_gym/envs/markets_execution_custom_metrics.py -> build/lib/abides_gym/envs
# copying abides_gym/envs/__init__.py -> build/lib/abides_gym/envs
# copying abides_gym/envs/markets_environment.py -> build/lib/abides_gym/envs
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/abides_gym
# creating build/bdist.linux-x86_64/egg/abides_gym/experimental_agents
# copying build/lib/abides_gym/experimental_agents/core_gym_agent.py -> build/bdist.linux-x86_64/egg/abides_gym/experimental_agents
# copying build/lib/abides_gym/experimental_agents/financial_gym_agent.py -> build/bdist.linux-x86_64/egg/abides_gym/experimental_agents
# copying build/lib/abides_gym/experimental_agents/__init__.py -> build/bdist.linux-x86_64/egg/abides_gym/experimental_agents
# creating build/bdist.linux-x86_64/egg/abides_gym/envs
# copying build/lib/abides_gym/envs/markets_execution_environment_v0.py -> build/bdist.linux-x86_64/egg/abides_gym/envs
# copying build/lib/abides_gym/envs/core_environment.py -> build/bdist.linux-x86_64/egg/abides_gym/envs
# copying build/lib/abides_gym/envs/markets_daily_investor_environment_v0.py -> build/bdist.linux-x86_64/egg/abides_gym/envs
# copying build/lib/abides_gym/envs/markets_execution_custom_metrics.py -> build/bdist.linux-x86_64/egg/abides_gym/envs
# copying build/lib/abides_gym/envs/__init__.py -> build/bdist.linux-x86_64/egg/abides_gym/envs
# copying build/lib/abides_gym/envs/markets_environment.py -> build/bdist.linux-x86_64/egg/abides_gym/envs
# copying build/lib/abides_gym/__init__.py -> build/bdist.linux-x86_64/egg/abides_gym
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/experimental_agents/core_gym_agent.py to core_gym_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/experimental_agents/financial_gym_agent.py to financial_gym_agent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/experimental_agents/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/envs/markets_execution_environment_v0.py to markets_execution_environment_v0.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/envs/core_environment.py to core_environment.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/envs/markets_daily_investor_environment_v0.py to markets_daily_investor_environment_v0.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/envs/markets_execution_custom_metrics.py to markets_execution_custom_metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/envs/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/envs/markets_environment.py to markets_environment.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/abides_gym/__init__.py to __init__.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_gym.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_gym.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_gym.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying abides_gym.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/abides_gym-0.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing abides_gym-0.0.0-py3.10.egg
# Copying abides_gym-0.0.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding abides-gym 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/abides_gym-0.0.0-py3.10.egg
# Processing dependencies for abides-gym==0.0.0
# Finished processing dependencies for abides-gym==0.0.0

# %%
# Install dependancies
# !python3.10 -m pip install pillow
# !python3.10 -m pip install ipython
# !python3.10 -m pip install ipykernel
# !python3.10 -m pip install matplotlib==3.10.0
# !python3.10 -m pip install coloredlogs==15.0.1
# !python3.10 -m pip install numpy==1.26.0
# !python3.10 -m pip install pandas==2.2.3
# !python3.10 -m pip install pomegranate==0.15
# !python3.10 -m pip install "ray[rllib]==2.42.0"
# !python3.10 -m pip install scipy==1.15.1
# !python3.10 -m pip install tqdm==4.67.1
# Out:
# Collecting pillow
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 63.2 MB/s eta 0:00:00
# Installing collected packages: pillow
# Successfully installed pillow-11.1.0
# Collecting ipython
#   Downloading ipython-8.33.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting decorator (from ipython)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup (from ipython)
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting pexpect>4.3 (from ipython)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython)
#   Downloading prompt_toolkit-3.0.50-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (2.19.1)
# Collecting stack_data (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing_extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.12.2)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython)
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython)
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipython-8.33.0-py3-none-any.whl (826 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.7/826.7 kB 25.1 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.6 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading prompt_toolkit-3.0.50-py3-none-any.whl (387 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, traitlets, prompt_toolkit, pexpect, parso, executing, exceptiongroup, decorator, asttokens, stack_data, matplotlib-inline, jedi, ipython
# Successfully installed asttokens-3.0.0 decorator-5.2.1 exceptiongroup-1.2.2 executing-2.2.0 ipython-8.33.0 jedi-0.19.2 matplotlib-inline-0.1.7 parso-0.8.4 pexpect-4.9.0 prompt_toolkit-3.0.50 ptyprocess-0.7.0 pure-eval-0.2.3 stack_data-0.6.3 traitlets-5.14.3 wcwidth-0.2.13
# Collecting ipykernel
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.8.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (8.33.0)
# Collecting jupyter-client>=6.1.12 (from ipykernel)
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel)
#   Downloading jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (0.1.7)
# Collecting nest-asyncio (from ipykernel)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel) (24.2)
# Collecting psutil (from ipykernel)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyzmq>=24 (from ipykernel)
#   Downloading pyzmq-26.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Collecting tornado>=6.1 (from ipykernel)
#   Downloading tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=6.1.12->ipykernel)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading debugpy-1.8.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 85.2 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading pyzmq-26.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.2/874.2 kB 42.7 MB/s eta 0:00:00
# Downloading tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (437 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Installing collected packages: tornado, pyzmq, python-dateutil, psutil, nest-asyncio, jupyter-core, debugpy, comm, jupyter-client, ipykernel
# Successfully installed comm-0.2.2 debugpy-1.8.12 ipykernel-6.29.5 jupyter-client-8.6.3 jupyter-core-5.7.2 nest-asyncio-1.6.0 psutil-7.0.0 python-dateutil-2.9.0.post0 pyzmq-26.2.1 tornado-6.4.2
# Collecting matplotlib==3.10.0
#   Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.10.0)
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib==3.10.0)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.10.0)
#   Downloading fonttools-4.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.10.0)
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Collecting numpy>=1.23 (from matplotlib==3.10.0)
#   Downloading numpy-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib==3.10.0) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.10.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.0) (1.16.0)
# Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 104.5 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 134.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.1 MB/s eta 0:00:00
# Downloading numpy-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 171.8 MB/s eta 0:00:00
# Installing collected packages: numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.0 numpy-2.2.3
# Collecting coloredlogs==15.0.1
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs==15.0.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Installing collected packages: humanfriendly, coloredlogs
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0
# Collecting numpy==1.26.0
#   Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 140.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
# Successfully installed numpy-1.26.0
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.3) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.3) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.2.3)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.3)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.16.0)
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 148.2 MB/s eta 0:00:00
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# Collecting pomegranate==0.15
#   Downloading pomegranate-0.15.0.tar.gz (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 19.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cython>=0.22.1 (from pomegranate==0.15)
#   Using cached Cython-3.0.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy<2.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from pomegranate==0.15) (1.26.0)
# Collecting joblib>=0.9.0b4 (from pomegranate==0.15)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting networkx>=2.4 (from pomegranate==0.15)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting scipy>=0.17.0 (from pomegranate==0.15)
#   Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from pomegranate==0.15) (6.0.2)
# Using cached Cython-3.0.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 85.3 MB/s eta 0:00:00
# Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
# Building wheels for collected packages: pomegranate
#   Building wheel for pomegranate (pyproject.toml) ... done
#   Created wheel for pomegranate: filename=pomegranate-0.15.0-cp310-cp310-linux_x86_64.whl size=21355465 sha256=b43389d2a22e4994c482ccc0ea8f35df4c025ce0395324e42e9b95a3279fe613
#   Stored in directory: /root/.cache/pip/wheels/55/44/b9/c0399e42f50907ada5da7d160bcd1465a39f36b935d9e59f5d
# Successfully built pomegranate
# Installing collected packages: scipy, networkx, joblib, cython, pomegranate
# Successfully installed cython-3.0.12 joblib-1.4.2 networkx-3.4.2 pomegranate-0.15.0 scipy-1.15.2
# Collecting ray==2.42.0 (from ray[rllib]==2.42.0)
#   Downloading ray-2.42.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.42.0->ray[rllib]==2.42.0) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray==2.42.0->ray[rllib]==2.42.0) (3.17.0)
# Collecting jsonschema (from ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray==2.42.0->ray[rllib]==2.42.0) (24.2)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray==2.42.0->ray[rllib]==2.42.0) (6.0.2)
# Collecting aiosignal (from ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting frozenlist (from ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray==2.42.0->ray[rllib]==2.42.0) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.42.0) (2.2.3)
# Collecting tensorboardX>=1.9 (from ray[rllib]==2.42.0)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting pyarrow>=9.0.0 (from ray[rllib]==2.42.0)
#   Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting fsspec (from ray[rllib]==2.42.0)
#   Downloading fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting dm-tree (from ray[rllib]==2.42.0)
#   Downloading dm_tree-0.1.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting gymnasium==1.0.0 (from ray[rllib]==2.42.0)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting lz4 (from ray[rllib]==2.42.0)
#   Downloading lz4-4.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting ormsgpack==1.7.0 (from ray[rllib]==2.42.0)
#   Downloading ormsgpack-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.42.0) (1.15.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[rllib]==2.42.0) (1.26.0)
# Collecting cloudpickle>=1.2.0 (from gymnasium==1.0.0->ray[rllib]==2.42.0)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[rllib]==2.42.0) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium==1.0.0->ray[rllib]==2.42.0)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting absl-py>=0.6.1 (from dm-tree->ray[rllib]==2.42.0)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.10/dist-packages (from dm-tree->ray[rllib]==2.42.0) (25.1.0)
# Collecting wrapt>=1.11.2 (from dm-tree->ray[rllib]==2.42.0)
#   Downloading wrapt-1.17.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray==2.42.0->ray[rllib]==2.42.0)
#   Downloading rpds_py-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]==2.42.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]==2.42.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]==2.42.0) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.42.0->ray[rllib]==2.42.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.42.0->ray[rllib]==2.42.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.42.0->ray[rllib]==2.42.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.42.0->ray[rllib]==2.42.0) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->ray[rllib]==2.42.0) (1.16.0)
# Downloading ray-2.42.0-cp310-cp310-manylinux2014_x86_64.whl (67.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 65.8 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 51.8 MB/s eta 0:00:00
# Downloading ormsgpack-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220 kB)
# Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (378 kB)
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 57.8 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
# Downloading dm_tree-0.1.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
# Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading lz4-4.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.6 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (386 kB)
# Downloading wrapt-1.17.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
# Installing collected packages: farama-notifications, wrapt, rpds-py, pyarrow, protobuf, ormsgpack, msgpack, lz4, fsspec, frozenlist, cloudpickle, absl-py, tensorboardX, referencing, gymnasium, dm-tree, aiosignal, jsonschema-specifications, jsonschema, ray
# Successfully installed absl-py-2.1.0 aiosignal-1.3.2 cloudpickle-3.1.1 dm-tree-0.1.9 farama-notifications-0.0.4 frozenlist-1.5.0 fsspec-2025.2.0 gymnasium-1.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 lz4-4.4.3 msgpack-1.1.0 ormsgpack-1.7.0 protobuf-5.29.3 pyarrow-19.0.1 ray-2.42.0 referencing-0.36.2 rpds-py-0.23.1 tensorboardX-2.6.2.2 wrapt-1.17.2
# Collecting scipy==1.15.1
#   Downloading scipy-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from scipy==1.15.1) (1.26.0)
# Downloading scipy-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 57.9 MB/s eta 0:00:00
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# Successfully installed scipy-1.15.1
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.10/dist-packages (4.67.1)

# %% [markdown]
# # Run simulations

# %%
# %%writefile simulation.py
import numpy as np
import pandas as pd
from abides_core import abides
from abides_core.utils import fmt_ts, ns_date, str_to_ns
from abides_markets.agents.value_agent import ValueAgent
from abides_markets.messages.market import MarketHoursRequestMsg
from abides_markets.configs import rmsc04
from abides_markets.utils import config_add_agents
from matplotlib import pyplot as plt

def max_distant_bid_ask_pair(bid_list, ask_list):
    # First, sort the lists by time (if not already sorted)
    bid_list = sorted(bid_list, key=lambda x: x[0])
    ask_list = sorted(ask_list, key=lambda x: x[0])

    max_diff = float('-inf')
    best_pair = None

    # Iterate over each ask (buy price)
    for ask_time, ask_price in ask_list:
        # Consider only bids that come after the ask time
        valid_bids = [(t, price) for t, price in bid_list if t > ask_time]
        if not valid_bids:
            continue
        # Find the bid with the maximum price among those valid bids
        max_bid_time, max_bid_price = max(valid_bids, key=lambda x: x[1])
        diff = max_bid_price - ask_price
        if diff > max_diff:
            max_diff = diff
            best_pair = ((ask_time, ask_price), (max_bid_time, max_bid_price))
    return best_pair


printed = False

# Import market data message types.
from abides_markets.messages.marketdata import L1SubReqMsg, L1DataMsg

# Import available order message types.
from abides_markets.messages.order import (
    LimitOrderMsg,
    MarketOrderMsg,
    PartialCancelOrderMsg,
    CancelOrderMsg,
    ModifyOrderMsg,
    ReplaceOrderMsg,
)

# Import the order classes and Side enum.
from abides_markets.orders import MarketOrder, Side

class AgentDQN(ValueAgent):
    def __init__(self, id,
                 name=None,
                 type="AgentDQN",
                 random_state=None,
                 symbol="ABM",
                 starting_cash=100_000,
                 sigma_n=10_000,
                 r_bar=100_000,
                 kappa=0.05,
                 sigma_s=100_000,
                 order_size_model=None,
                 lambda_a=0.00001,
                 log_orders=True):
        if name is None:
            name = f"AgentDQN_{id}"
        super().__init__(id, name, type, random_state, symbol, starting_cash,
                         sigma_n, r_bar, kappa, sigma_s, order_size_model, lambda_a, log_orders)
        # Ensure holdings include the symbol for mark-to-market calculations.
        if self.symbol not in self.holdings:
            self.holdings[self.symbol] = 0
        # Initialize last_trade for the symbol with a default price.
        if self.symbol not in self.last_trade:
            self.last_trade[self.symbol] = 100000
        self.price_history = []  # (simulation time, last_price, msg_timestamp, bid, ask)
        self.last_price = None
        self.msg_timestamp = None
        self.bid = None
        self.ask = None
        self.subscribed = False
        self.buy_order_sent = False
        self.sell_order_sent = False
        self.wakeup_count = 0
        self.buy_price = None
        self.sell_price = None

    def kernel_starting(self, start_time):
        super().kernel_starting(start_time)
        print(f"{self.name} starting with CASH: {self.holdings['CASH']}")
        if not self.subscribed:
            self.send_message(self.exchange_id, L1SubReqMsg(self.symbol))
            self.subscribed = True

    def receive_message(self, current_time, sender_id, message):
        super().receive_message(current_time, sender_id, message)
        if isinstance(message, L1DataMsg):
            new_data = (message.last_transaction, message.exchange_ts, message.bid, message.ask)
            if new_data == (self.last_price, self.msg_timestamp, self.bid, self.ask):
                return
            self.last_price = message.last_transaction
            self.msg_timestamp = message.exchange_ts
            self.bid = message.bid
            self.ask = message.ask
            self.price_history.append((current_time, self.last_price, self.msg_timestamp, self.bid, self.ask))
            print(f"\n{50*'='}")
            print(f"Timestamp: {self.msg_timestamp}")
            print(f"{self.name} received L1DataMsg: last_price = {self.last_price} at ts: {self.msg_timestamp}")
            print(f"L1DataMsg: last_bid = {self.bid} and last_ask = {self.ask}")
            print(50*"=", "\n")

    def wakeup(self, current_time):
        self.current_time = current_time
        self.wakeup_count += 1
        if self.mkt_open is None:
            self.send_message(self.exchange_id, MarketHoursRequestMsg())
        if not self.mkt_open or not self.mkt_close:
            return
        else:
            if not self.trading:
                self.trading = True

        # TODO:
        # The DQN SHOULD:
            # BE DEFINED OUTSIDE THE CLASS TO BE PERSISTENT THROUGH SIMULATIONS
            # BE CALLED HERE
            # RECIEVE self.price_history + ...
            # IT SHOULD OUTPUT: BUY / SELL / WAIT
            # BE ABLE TO BUY AND SELL ONLY ONCE PER DAY

        # BUY BLOCK:
        if not self.buy_order_sent and self.wakeup_count == 10: # On the 10th wakeup, send a BUY market order.
            buy_order = MarketOrder(
                agent_id=self.id,
                time_placed=current_time,
                symbol=self.symbol,
                quantity=1,
                side=Side.BID
            )
            buy_msg = MarketOrderMsg(order=buy_order)
            self.send_message(self.exchange_id, buy_msg)
            self.buy_price = self.last_price if self.last_price is not None else 100000
            print(f"{self.name} sent BUY market order on wakeup {self.wakeup_count} (recorded price: {self.buy_price})")
            self.buy_order_sent = True

        # SELL BLOCK
        if not self.sell_order_sent and self.wakeup_count == 100: # On the 100th wakeup, send a SELL market order.
            sell_order = MarketOrder(
                agent_id=self.id,
                time_placed=current_time,
                symbol=self.symbol,
                quantity=1,
                side=Side.ASK
            )
            sell_msg = MarketOrderMsg(order=sell_order)
            self.send_message(self.exchange_id, sell_msg)
            self.sell_price = self.last_price if self.last_price is not None else 100000
            print(f"{self.name} sent SELL market order on wakeup {self.wakeup_count} (recorded price: {self.sell_price})")
            self.sell_order_sent = True


        self.set_wakeup(current_time + int(1e9))

    def order_executed(self, order):
        super().order_executed(order)
        if order.side.is_bid():
            if order.fill_price is not None:
                self.buy_price = order.fill_price
                print(f"{self.name} updated BUY price to: {self.buy_price} from execution")
        elif order.side.is_ask():
            if order.fill_price is not None:
                self.sell_price = order.fill_price
                print(f"{self.name} updated SELL price to: {self.sell_price} from execution")

    def kernel_stopping(self):
        global printed
        if printed:
            return
        else:
            printed = True
        print(f"\n{50*'='}")
        print(f"{self.name} stopping with CASH: {self.holdings['CASH']}")
        self.update_agent_state({"price_history": self.price_history})
        if self.price_history:
            print(f"{self.name} price history head (first 5 records):")
            for record in self.price_history[:5]:
                sim_time, last_price, msg_ts, bid, ask = record
                print(f"sim_time: {fmt_ts(sim_time)}, last_price: {last_price}, msg_ts: {msg_ts}, bid: {bid}, ask: {ask}")
        else:
            print(f"{self.name} did not record any market data.")
        print(f"{self.name} final BUY price: {self.buy_price}")
        print(f"{self.name} final SELL price: {self.sell_price}")
        super().kernel_stopping()

def build_custom_config():
    config = rmsc04.build_config(end_time="09:35:00")
    custom_agent = AgentDQN(id=len(config['agents']))
    config['agents'].append(custom_agent)
    config = config_add_agents(config, [custom_agent])
    return config

config = build_custom_config()
end_state = abides.run(config)

order_book = end_state["agents"][0].order_books["ABM"]
L1 = order_book.get_L1_snapshots()

# Create DataFrames for best bids and best asks.
best_bids = pd.DataFrame(L1["best_bids"], columns=["time", "price", "qty"])
best_asks = pd.DataFrame(L1["best_asks"], columns=["time", "price", "qty"])

best_bids["time"] = best_bids["time"].apply(lambda x: x - ns_date(x))
best_asks["time"] = best_asks["time"].apply(lambda x: x - ns_date(x))

# Extract the bid and ask price lists as (time, price) tuples.
bid_list = list(zip(best_bids["time"].tolist(), best_bids["price"].tolist()))
ask_list = list(zip(best_asks["time"].tolist(), best_asks["price"].tolist()))

# Filter out any None values in the prices.
bid_list = [(t, p) for t, p in bid_list if p is not None]
ask_list = [(t, p) for t, p in ask_list if p is not None]

pair = max_distant_bid_ask_pair(bid_list, ask_list)
if pair is not None:
    ((bid_time, bid_price), (ask_time, ask_price)) = pair
    print("\nBest possible single trade in the simulation:")
    print(f"Bid - Time: {bid_time}, Buy_Price: {bid_price}")
    print(f"Ask - Time: {ask_time}, Sell_Price: {ask_price}")
    print(f"Profit: {ask_price - bid_price}")
else:
    print("No valid bid/ask pair found.")
# Out:
# Writing simulation.py

# %%
# !python3.10 simulation.py
# Out:
# /usr/local/lib/python3.10/dist-packages/abides_core-0.0.0-py3.10.egg/abides_core/utils.py:97: FutureWarning: 'S' is deprecated and will be removed in a future version. Please use 's' instead of 'S'.
# [3797] INFO abides Simulation Start Time: 2025-03-01 18:55:38.272799
# AgentDQN_1117 starting with CASH: 100000
# AgentDQN_1117 starting with CASH: 100000
# [3797] INFO abides_core.kernel --- Simulation time: 2021-02-05 00:00:00, messages processed: 0, wallclock elapsed: 0.00s ---
#
# ==================================================
# Timestamp: 1612517400386472732
# AgentDQN_1117 received L1DataMsg: last_price = 100000 at ts: 1612517400386472732
# L1DataMsg: last_bid = None and last_ask = (100027, 100)
# ==================================================
#
# AgentDQN_1117 sent BUY market order on wakeup 10 (recorded price: 100000)
# /usr/local/lib/python3.10/dist-packages/abides_markets-0.0.0-py3.10.egg/abides_markets/agents/trading_agent.py:790: UserWarning: Execution received for order not in orders list: (Agent 1117 @ 2021-02-05 09:30:07) : MKT Order BID 1 ABM
# AgentDQN_1117 updated BUY price to: 99999 from execution
#
# ==================================================
# Timestamp: 1612517442922017898
# AgentDQN_1117 received L1DataMsg: last_price = 99987 at ts: 1612517442922017898
# L1DataMsg: last_bid = (99986, 200) and last_ask = (99987, 452)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517478753678788
# AgentDQN_1117 received L1DataMsg: last_price = 99981 at ts: 1612517478753678788
# L1DataMsg: last_bid = (99980, 217) and last_ask = (99981, 289)
# ==================================================
#
# AgentDQN_1117 sent SELL market order on wakeup 100 (recorded price: 99981)
# /usr/local/lib/python3.10/dist-packages/abides_markets-0.0.0-py3.10.egg/abides_markets/agents/trading_agent.py:790: UserWarning: Execution received for order not in orders list: (Agent 1117 @ 2021-02-05 09:31:37) : MKT Order ASK 1 ABM
# AgentDQN_1117 updated SELL price to: 99981 from execution
#
# ==================================================
# Timestamp: 1612517498242754908
# AgentDQN_1117 received L1DataMsg: last_price = 99981 at ts: 1612517498242754908
# L1DataMsg: last_bid = (99981, 10) and last_ask = (99982, 13)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517502748464892
# AgentDQN_1117 received L1DataMsg: last_price = 99982 at ts: 1612517502748464892
# L1DataMsg: last_bid = (99981, 10) and last_ask = (99982, 101)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517512060563532
# AgentDQN_1117 received L1DataMsg: last_price = 99982 at ts: 1612517512060563532
# L1DataMsg: last_bid = (99982, 267) and last_ask = (99984, 52)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517527068972561
# AgentDQN_1117 received L1DataMsg: last_price = 99982 at ts: 1612517527068972561
# L1DataMsg: last_bid = (99982, 24) and last_ask = (99983, 527)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517528503107893
# AgentDQN_1117 received L1DataMsg: last_price = 99983 at ts: 1612517528503107893
# L1DataMsg: last_bid = (99982, 24) and last_ask = (99983, 336)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517538761828896
# AgentDQN_1117 received L1DataMsg: last_price = 99982 at ts: 1612517538761828896
# L1DataMsg: last_bid = (99981, 110) and last_ask = (99983, 436)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517541228466198
# AgentDQN_1117 received L1DataMsg: last_price = 99983 at ts: 1612517541228466198
# L1DataMsg: last_bid = (99981, 110) and last_ask = (99984, 52)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517546702798172
# AgentDQN_1117 received L1DataMsg: last_price = 99984 at ts: 1612517546702798172
# L1DataMsg: last_bid = (99984, 190) and last_ask = (99985, 183)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517559521166231
# AgentDQN_1117 received L1DataMsg: last_price = 99986 at ts: 1612517559521166231
# L1DataMsg: last_bid = (99985, 214) and last_ask = (99986, 142)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517560900558580
# AgentDQN_1117 received L1DataMsg: last_price = 99985 at ts: 1612517560900558580
# L1DataMsg: last_bid = (99985, 114) and last_ask = (99986, 242)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517565390206643
# AgentDQN_1117 received L1DataMsg: last_price = 99986 at ts: 1612517565390206643
# L1DataMsg: last_bid = (99985, 114) and last_ask = (99986, 100)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517566721799525
# AgentDQN_1117 received L1DataMsg: last_price = 99986 at ts: 1612517566721799525
# L1DataMsg: last_bid = (99985, 214) and last_ask = (99986, 100)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517581221041321
# AgentDQN_1117 received L1DataMsg: last_price = 99986 at ts: 1612517581221041321
# L1DataMsg: last_bid = (99985, 114) and last_ask = (99986, 118)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517590092632016
# AgentDQN_1117 received L1DataMsg: last_price = 99986 at ts: 1612517590092632016
# L1DataMsg: last_bid = (99986, 141) and last_ask = (99987, 172)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517600287497647
# AgentDQN_1117 received L1DataMsg: last_price = 99987 at ts: 1612517600287497647
# L1DataMsg: last_bid = (99987, 128) and last_ask = (99988, 201)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517600740571685
# AgentDQN_1117 received L1DataMsg: last_price = 99987 at ts: 1612517600740571685
# L1DataMsg: last_bid = (99987, 113) and last_ask = (99988, 201)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517624051675351
# AgentDQN_1117 received L1DataMsg: last_price = 99997 at ts: 1612517624051675351
# L1DataMsg: last_bid = (99988, 89) and last_ask = (99997, 1)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517624410643460
# AgentDQN_1117 received L1DataMsg: last_price = 99997 at ts: 1612517624410643460
# L1DataMsg: last_bid = (99997, 62) and last_ask = (99999, 93)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517637326140271
# AgentDQN_1117 received L1DataMsg: last_price = 100010 at ts: 1612517637326140271
# L1DataMsg: last_bid = (100010, 62) and last_ask = (100018, 100)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517646041484859
# AgentDQN_1117 received L1DataMsg: last_price = 100010 at ts: 1612517646041484859
# L1DataMsg: last_bid = (100010, 62) and last_ask = (100018, 100)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517650639444480
# AgentDQN_1117 received L1DataMsg: last_price = 100010 at ts: 1612517650639444480
# L1DataMsg: last_bid = (100010, 62) and last_ask = (100018, 100)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517652367167131
# AgentDQN_1117 received L1DataMsg: last_price = 100011 at ts: 1612517652367167131
# L1DataMsg: last_bid = (100010, 62) and last_ask = (100011, 300)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517659775735644
# AgentDQN_1117 received L1DataMsg: last_price = 100010 at ts: 1612517659775735644
# L1DataMsg: last_bid = (100008, 100) and last_ask = (100010, 38)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517661356703774
# AgentDQN_1117 received L1DataMsg: last_price = 100010 at ts: 1612517661356703774
# L1DataMsg: last_bid = (100008, 100) and last_ask = (100010, 54)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517662424385520
# AgentDQN_1117 received L1DataMsg: last_price = 100009 at ts: 1612517662424385520
# L1DataMsg: last_bid = (100009, 31) and last_ask = (100010, 54)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517664551509065
# AgentDQN_1117 received L1DataMsg: last_price = 100009 at ts: 1612517664551509065
# L1DataMsg: last_bid = (100009, 31) and last_ask = (100010, 254)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517673580157253
# AgentDQN_1117 received L1DataMsg: last_price = 100009 at ts: 1612517673580157253
# L1DataMsg: last_bid = (100007, 12) and last_ask = (100009, 25)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517676947295783
# AgentDQN_1117 received L1DataMsg: last_price = 100009 at ts: 1612517676947295783
# L1DataMsg: last_bid = (100007, 12) and last_ask = (100009, 104)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517684995415810
# AgentDQN_1117 received L1DataMsg: last_price = 100006 at ts: 1612517684995415810
# L1DataMsg: last_bid = (100003, 100) and last_ask = (100006, 92)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517693567809744
# AgentDQN_1117 received L1DataMsg: last_price = 100006 at ts: 1612517693567809744
# L1DataMsg: last_bid = (100006, 94) and last_ask = (100007, 188)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517696757773270
# AgentDQN_1117 received L1DataMsg: last_price = 100006 at ts: 1612517696757773270
# L1DataMsg: last_bid = (100004, 200) and last_ask = (100006, 6)
# ==================================================
#
#
# ==================================================
# Timestamp: 1612517698150579953
# AgentDQN_1117 received L1DataMsg: last_price = 100004 at ts: 1612517698150579953
# L1DataMsg: last_bid = (100004, 100) and last_ask = (100006, 6)
# ==================================================
#
#
# ==================================================
# AgentDQN_1117 stopping with CASH: 99982
# AgentDQN_1117 price history head (first 5 records):
# sim_time: 2021-02-05 09:30:00, last_price: 100000, msg_ts: 1612517400386472732, bid: None, ask: (100027, 100)
# sim_time: 2021-02-05 09:30:42, last_price: 99987, msg_ts: 1612517442922017898, bid: (99986, 200), ask: (99987, 452)
# sim_time: 2021-02-05 09:31:18, last_price: 99981, msg_ts: 1612517478753678788, bid: (99980, 217), ask: (99981, 289)
# sim_time: 2021-02-05 09:31:38, last_price: 99981, msg_ts: 1612517498242754908, bid: (99981, 10), ask: (99982, 13)
# sim_time: 2021-02-05 09:31:42, last_price: 99982, msg_ts: 1612517502748464892, bid: (99981, 10), ask: (99982, 101)
# AgentDQN_1117 final BUY price: 99999
# AgentDQN_1117 final SELL price: 99981
# [3797] INFO abides_core.kernel Event Queue elapsed: 0:00:01.325190, messages: 12,855, messages per second: 9700.5
# [3797] INFO abides_core.kernel Mean ending value by agent type:
# [3797] INFO abides_core.kernel NoiseAgent: 3
# [3797] INFO abides_core.kernel ValueAgent: -11
# [3797] INFO abides_core.kernel AdaptivePOVMarketMakerAgent: -873
# [3797] INFO abides_core.kernel MomentumAgent: 0
# [3797] INFO abides_core.kernel AgentDQN: -18
# [3797] INFO abides_core.kernel Simulation ending!
# [3797] INFO abides Simulation End Time: 2025-03-01 18:55:41.421518
# [3797] INFO abides Time taken to run simulation: 0:00:03.148719
#
# Best possible single trade in the simulation:
# Bid - Time: 34202301632768.0, Buy_Price: 99945.0
# Ask - Time: 34435338843648.0, Sell_Price: 100010
# Profit: 65.0

# %%
# plt.plot(best_bids.time, best_bids.price, label='Best Bids')
# plt.plot(best_asks.time, best_asks.price, label='Best Asks')
# band = 250
# plt.ylim(100_000 - band, 100_000 + band)
# time_mesh = np.arange(str_to_ns("09:30:00"), str_to_ns("11:40:00"), int(1e9 * 60 * 10))
# plt.xticks(time_mesh, [fmt_ts(time).split(" ")[1] for time in time_mesh], rotation=60)
# plt.xlabel('Time')
# plt.ylabel('Price')
# plt.legend()
# plt.title('Best Bids and Asks Over Time')
# plt.show()
